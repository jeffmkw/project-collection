# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import numpy as np

# %%
data1 = pd.read_csv('C:/Users/Jeffery/Google Drive/Homework/project/cleaned independent factors.csv')
data2 = pd.read_excel('C:/Users/Jeffery/Google Drive/Homework/project/Construction Projects.xlsx')
data3 = pd.read_excel('C:/Users/Jeffery/Google Drive/Homework/project/final data.xlsx')

# %%
data1.head(2)
# Out:
#    year month str  overall_unemployment_rate  labor_force  employment  \
# 0  2014   January                        6.6       155295      145055
# 1  2014  February                        6.7       155485      145102
#
#    unemployment  workforce_in_construction  unemployment_rate_in_construction  \
# 0         10240                       5989                               12.3
# 1         10383                       6010                               12.8
#
#         IPI  construction_value      CPI  temperature  month
# 0  102.6063              954642  235.385         31.9      1
# 1  103.6292              947088  235.672         35.3      2

# %%
data2.head(2)
# Out:
#         Date  Public  Private   Total  month  year
# 0 2014-01-01  260580   694062  954642      1  2014
# 1 2014-02-01  260887   686201  947088      2  2014

# %%
data3.head(2)
# Out:
#   BILL_RUN_DATE  year month_nm Division        sales  dayofweek  week  month
# 0    2014-01-03  2014      Jan        C  2527858.254          4     1      1
# 1    2014-01-03  2014      Jan        S    84509.652          4     1      1

# %%
data3 = data3.loc[data3['year'].isin([2014, 2015,2016])]

# %%
data = data3
data = pd.merge(data, data2, on = ['month','year'], how = 'left')
data = pd.merge(data, data1, on = ['month','year'], how = 'left')

# %%
data.shape
# Out:
# (17088, 23)

# %%
data.head(5)
# Out:
#   BILL_RUN_DATE  year month_nm Division        sales  dayofweek  week  month  \
# 0    2014-01-03  2014      Jan        C  2527858.254          4     1      1
# 1    2014-01-03  2014      Jan        S    84509.652          4     1      1
# 2    2014-01-03  2014      Jan        G     1027.920          4     1      1
# 3    2014-01-03  2014      Jan        F     2113.662          4     1      1
# 4    2014-01-03  2014      Jan        K   341143.206          4     1      1
#
#         Date  Public     ...       overall_unemployment_rate  labor_force  \
# 0 2014-01-01  260580     ...                             6.6       155295
# 1 2014-01-01  260580     ...                             6.6       155295
# 2 2014-01-01  260580     ...                             6.6       155295
# 3 2014-01-01  260580     ...                             6.6       155295
# 4 2014-01-01  260580     ...                             6.6       155295
#
#   employment  unemployment  workforce_in_construction  \
# 0     145055         10240                       5989
# 1     145055         10240                       5989
# 2     145055         10240                       5989
# 3     145055         10240                       5989
# 4     145055         10240                       5989
#
#    unemployment_rate_in_construction       IPI  construction_value      CPI  \
# 0                               12.3  102.6063              954642  235.385
# 1                               12.3  102.6063              954642  235.385
# 2                               12.3  102.6063              954642  235.385
# 3                               12.3  102.6063              954642  235.385
# 4                               12.3  102.6063              954642  235.385
#
#    temperature
# 0         31.9
# 1         31.9
# 2         31.9
# 3         31.9
# 4         31.9
#
# [5 rows x 23 columns]

# %%
data.columns
# Out:
# Index(['BILL_RUN_DATE', 'year', 'month_nm', 'Division', 'sales', 'dayofweek',
#        'week', 'month', 'Date', 'Public', 'Private', 'Total', 'month str',
#        'overall_unemployment_rate', 'labor_force', 'employment',
#        'unemployment', 'workforce_in_construction',
#        'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
#        'temperature'],
#       dtype='object')

# %%
month = data.groupby(['year', 'month'], as_index=False)['sales'].sum()

month = pd.merge(month, data2, on = ['month','year'], how = 'left')
month = pd.merge(month, data1, on = ['month','year'], how = 'left')
del month['Date']
del month['month str']
month.head(10)
# Out:
#    year  month         sales  Public  Private   Total  \
# 0  2014      1  7.132159e+07  260580   694062  954642
# 1  2014      2  7.045462e+07  260887   686201  947088
# 2  2014      3  7.934422e+07  264972   682331  947303
# 3  2014      4  7.823823e+07  270530   684588  955118
# 4  2014      5  7.699178e+07  273317   682820  956137
# 5  2014      6  8.014754e+07  272854   684266  957120
# 6  2014      7  7.759557e+07  277224   682819  960043
# 7  2014      8  7.796993e+07  276685   684382  961067
# 8  2014      9  7.939032e+07  272291   688027  960318
# 9  2014     10  9.052564e+07  278593   692396  970989
#
#    overall_unemployment_rate  labor_force  employment  unemployment  \
# 0                        6.6       155295      145055         10240
# 1                        6.7       155485      145102         10383
# 2                        6.7       156115      145715         10400
# 3                        6.2       155378      145673          9705
# 4                        6.3       155559      145819          9740
# 5                        6.1       155682      146222          9460
# 6                        6.2       156098      146461          9637
# 7                        6.2       156117      146501          9616
# 8                        5.9       156100      146845          9255
# 9                        5.7       156389      147426          8964
#
#    workforce_in_construction  unemployment_rate_in_construction       IPI  \
# 0                       5989                               12.3  102.6063
# 1                       6010                               12.8  103.6292
# 2                       6047                               11.3  104.5546
# 3                       6086                                9.4  104.7807
# 4                       6112                                8.6  105.0799
# 5                       6132                                8.2  105.4698
# 6                       6174                                7.5  105.4919
# 7                       6204                                7.7  105.4250
# 8                       6231                                7.0  105.7329
# 9                       6251                                6.4  105.7898
#
#    construction_value      CPI  temperature
# 0              954642  235.385         31.9
# 1              947088  235.672         35.3
# 2              947303  235.978         42.4
# 3              955118  236.471         52.0
# 4              956137  236.832         60.8
# 5              957120  237.029         68.7
# 6              960043  237.424         73.3
# 7              961067  237.256         72.1
# 8              960318  237.486         65.2
# 9              970989  237.506         54.8

# %%
week = data.groupby(['year','week','month'],as_index=False)['sales'].sum()
week = pd.merge(week, data2, on = ['month','year'], how = 'left')
week = pd.merge(week, data1, on = ['month','year'], how = 'left')
#week = data.groupby(['year','week'],as_index=False)['sales'].sum()
#del week['Date']
#del week['month str']

# %%
week.columns
# Out:
# Index(['year', 'week', 'month', 'sales', 'Date', 'Public', 'Private', 'Total',
#        'month str', 'overall_unemployment_rate', 'labor_force', 'employment',
#        'unemployment', 'workforce_in_construction',
#        'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
#        'temperature'],
#       dtype='object')

# %%
#data.to_excel('C:/Users/Jeffery/Google Drive/Homework/IOWA/Jeffery/data.xlsx')
#month.to_excel('C:/Users/Jeffery/Google Drive/Homework/IOWA/Jeffery/month.xlsx')
#week.to_excel('C:/Users/Jeffery/Google Drive/Homework/IOWA/Jeffery/week.xlsx')

# %% [markdown]
# visual

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#figure for month
corr = month.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
corr
# Out:
#                                        year     month     sales    Public  \
# year                               1.000000  0.000000 -0.014078  0.460931
# month                              0.000000  1.000000  0.212375  0.242997
# sales                             -0.014078  0.212375  1.000000  0.267600
# Public                             0.460931  0.242997  0.267600  1.000000
# Private                            0.942143  0.246944 -0.005771  0.515845
# Total                              0.932175  0.261093  0.031388  0.612950
# overall_unemployment_rate         -0.886104 -0.346877 -0.152046 -0.667838
# labor_force                        0.951151  0.205509 -0.008295  0.390572
# employment                         0.956757  0.273143  0.055367  0.522293
# unemployment                      -0.872924 -0.356650 -0.153523 -0.685988
# workforce_in_construction          0.942793  0.303605  0.053738  0.586441
# unemployment_rate_in_construction -0.521923 -0.596794 -0.324354 -0.529920
# IPI                               -0.722135  0.119543  0.130476 -0.281172
# construction_value                 0.932175  0.261093  0.031388  0.612950
# CPI                                0.710571  0.527832  0.042090  0.261198
# temperature                        0.000000  0.243640  0.404310  0.147160
#
#                                     Private     Total  \
# year                               0.942143  0.932175
# month                              0.246944  0.261093
# sales                             -0.005771  0.031388
# Public                             0.515845  0.612950
# Private                            1.000000  0.993070
# Total                              0.993070  1.000000
# overall_unemployment_rate         -0.897896 -0.919750
# labor_force                        0.952121  0.931725
# employment                         0.963071  0.959895
# unemployment                      -0.887340 -0.912504
# workforce_in_construction          0.960277  0.966118
# unemployment_rate_in_construction -0.614810 -0.639739
# IPI                               -0.780791 -0.758699
# construction_value                 0.993070  1.000000
# CPI                                0.832542  0.803690
# temperature                        0.044039  0.060806
#
#                                    overall_unemployment_rate  labor_force  \
# year                                               -0.886104     0.951151
# month                                              -0.346877     0.205509
# sales                                              -0.152046    -0.008295
# Public                                             -0.667838     0.390572
# Private                                            -0.897896     0.952121
# Total                                              -0.919750     0.931725
# overall_unemployment_rate                           1.000000    -0.863574
# labor_force                                        -0.863574     1.000000
# employment                                         -0.950035     0.977555
# unemployment                                        0.998448    -0.846012
# workforce_in_construction                          -0.968354     0.952627
# unemployment_rate_in_construction                   0.721500    -0.583940
# IPI                                                 0.521511    -0.668294
# construction_value                                 -0.919750     0.931725
# CPI                                                -0.711030     0.827825
# temperature                                        -0.071778     0.029131
#
#                                    employment  unemployment  \
# year                                 0.956757     -0.872924
# month                                0.273143     -0.356650
# sales                                0.055367     -0.153523
# Public                               0.522293     -0.685988
# Private                              0.963071     -0.887340
# Total                                0.959895     -0.912504
# overall_unemployment_rate           -0.950035      0.998448
# labor_force                          0.977555     -0.846012
# employment                           1.000000     -0.939351
# unemployment                        -0.939351      1.000000
# workforce_in_construction            0.992623     -0.961272
# unemployment_rate_in_construction   -0.664830      0.731953
# IPI                                 -0.630870      0.508755
# construction_value                   0.959895     -0.912504
# CPI                                  0.808375     -0.698193
# temperature                          0.053351     -0.087746
#
#                                    workforce_in_construction  \
# year                                                0.942793
# month                                               0.303605
# sales                                               0.053738
# Public                                              0.586441
# Private                                             0.960277
# Total                                               0.966118
# overall_unemployment_rate                          -0.968354
# labor_force                                         0.952627
# employment                                          0.992623
# unemployment                                       -0.961272
# workforce_in_construction                           1.000000
# unemployment_rate_in_construction                  -0.687269
# IPI                                                -0.628018
# construction_value                                  0.966118
# CPI                                                 0.786423
# temperature                                         0.057882
#
#                                    unemployment_rate_in_construction  \
# year                                                       -0.521923
# month                                                      -0.596794
# sales                                                      -0.324354
# Public                                                     -0.529920
# Private                                                    -0.614810
# Total                                                      -0.639739
# overall_unemployment_rate                                   0.721500
# labor_force                                                -0.583940
# employment                                                 -0.664830
# unemployment                                                0.731953
# workforce_in_construction                                  -0.687269
# unemployment_rate_in_construction                           1.000000
# IPI                                                         0.225683
# construction_value                                         -0.639739
# CPI                                                        -0.684957
# temperature                                                -0.650741
#
#                                         IPI  construction_value       CPI  \
# year                              -0.722135            0.932175  0.710571
# month                              0.119543            0.261093  0.527832
# sales                              0.130476            0.031388  0.042090
# Public                            -0.281172            0.612950  0.261198
# Private                           -0.780791            0.993070  0.832542
# Total                             -0.758699            1.000000  0.803690
# overall_unemployment_rate          0.521511           -0.919750 -0.711030
# labor_force                       -0.668294            0.931725  0.827825
# employment                        -0.630870            0.959895  0.808375
# unemployment                       0.508755           -0.912504 -0.698193
# workforce_in_construction         -0.628018            0.966118  0.786423
# unemployment_rate_in_construction  0.225683           -0.639739 -0.684957
# IPI                                1.000000           -0.758699 -0.530727
# construction_value                -0.758699            1.000000  0.803690
# CPI                               -0.530727            0.803690  1.000000
# temperature                        0.064993            0.060806  0.243463
#
#                                    temperature
# year                                  0.000000
# month                                 0.243640
# sales                                 0.404310
# Public                                0.147160
# Private                               0.044039
# Total                                 0.060806
# overall_unemployment_rate            -0.071778
# labor_force                           0.029131
# employment                            0.053351
# unemployment                         -0.087746
# workforce_in_construction             0.057882
# unemployment_rate_in_construction    -0.650741
# IPI                                   0.064993
# construction_value                    0.060806
# CPI                                   0.243463
# temperature                           1.000000

# %%
#figure for month
corr = week.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
corr
# Out:
#                                        year      week     month     sales  \
# year                               1.000000  0.018335  0.011105 -0.025487
# week                               0.018335  1.000000  0.963952  0.018863
# month                              0.011105  0.963952  1.000000 -0.004655
# sales                             -0.025487  0.018863 -0.004655  1.000000
# Public                             0.451074  0.245725  0.243598  0.016478
# Private                            0.944056  0.254884  0.254571 -0.041982
# Total                              0.934051  0.269128  0.268547 -0.036542
# overall_unemployment_rate         -0.886494 -0.348590 -0.355840  0.001564
# labor_force                        0.952382  0.206397  0.209517 -0.035212
# employment                         0.958164  0.273471  0.278930 -0.023567
# unemployment                      -0.873221 -0.356472 -0.365212  0.002158
# workforce_in_construction          0.943727  0.306469  0.311116 -0.023764
# unemployment_rate_in_construction -0.527730 -0.585102 -0.590310  0.009745
# IPI                               -0.728703  0.081299  0.107030  0.066981
# construction_value                 0.934051  0.269128  0.268547 -0.036542
# CPI                                0.714266  0.527370  0.529914 -0.040313
# temperature                       -0.003053  0.246686  0.225934  0.009692
#
#                                      Public   Private     Total  \
# year                               0.451074  0.944056  0.934051
# week                               0.245725  0.254884  0.269128
# month                              0.243598  0.254571  0.268547
# sales                              0.016478 -0.041982 -0.036542
# Public                             1.000000  0.504158  0.602598
# Private                            0.504158  1.000000  0.993005
# Total                              0.602598  0.993005  1.000000
# overall_unemployment_rate         -0.660206 -0.900297 -0.922206
# labor_force                        0.377396  0.952473  0.931756
# employment                         0.510683  0.964651  0.961232
# unemployment                      -0.678937 -0.889574 -0.914858
# workforce_in_construction          0.576365  0.961977  0.967741
# unemployment_rate_in_construction -0.518982 -0.615108 -0.639361
# IPI                               -0.279005 -0.785831 -0.764314
# construction_value                 0.602598  0.993005  1.000000
# CPI                                0.245650  0.831945  0.802367
# temperature                        0.137858  0.033837  0.050115
#
#                                    overall_unemployment_rate  labor_force  \
# year                                               -0.886494     0.952382
# week                                               -0.348590     0.206397
# month                                              -0.355840     0.209517
# sales                                               0.001564    -0.035212
# Public                                             -0.660206     0.377396
# Private                                            -0.900297     0.952473
# Total                                              -0.922206     0.931756
# overall_unemployment_rate                           1.000000    -0.862218
# labor_force                                        -0.862218     1.000000
# employment                                         -0.949257     0.977510
# unemployment                                        0.998405    -0.844274
# workforce_in_construction                          -0.967906     0.952203
# unemployment_rate_in_construction                   0.722259    -0.582148
# IPI                                                 0.533907    -0.676298
# construction_value                                 -0.922206     0.931756
# CPI                                                -0.711763     0.827945
# temperature                                        -0.063233     0.020080
#
#                                    employment  unemployment  \
# year                                 0.958164     -0.873221
# week                                 0.273471     -0.356472
# month                                0.278930     -0.365212
# sales                               -0.023567      0.002158
# Public                               0.510683     -0.678937
# Private                              0.964651     -0.889574
# Total                                0.961232     -0.914858
# overall_unemployment_rate           -0.949257      0.998405
# labor_force                          0.977510     -0.844274
# employment                           1.000000     -0.938305
# unemployment                        -0.938305      1.000000
# workforce_in_construction            0.992463     -0.960660
# unemployment_rate_in_construction   -0.663916      0.732615
# IPI                                 -0.641426      0.521139
# construction_value                   0.961232     -0.914858
# CPI                                  0.809087     -0.698456
# temperature                          0.044072     -0.079231
#
#                                    workforce_in_construction  \
# year                                                0.943727
# week                                                0.306469
# month                                               0.311116
# sales                                              -0.023764
# Public                                              0.576365
# Private                                             0.961977
# Total                                               0.967741
# overall_unemployment_rate                          -0.967906
# labor_force                                         0.952203
# employment                                          0.992463
# unemployment                                       -0.960660
# workforce_in_construction                           1.000000
# unemployment_rate_in_construction                  -0.687364
# IPI                                                -0.638875
# construction_value                                  0.967741
# CPI                                                 0.787054
# temperature                                         0.048973
#
#                                    unemployment_rate_in_construction  \
# year                                                       -0.527730
# week                                                       -0.585102
# month                                                      -0.590310
# sales                                                       0.009745
# Public                                                     -0.518982
# Private                                                    -0.615108
# Total                                                      -0.639361
# overall_unemployment_rate                                   0.722259
# labor_force                                                -0.582148
# employment                                                 -0.663916
# unemployment                                                0.732615
# workforce_in_construction                                  -0.687364
# unemployment_rate_in_construction                           1.000000
# IPI                                                         0.235538
# construction_value                                         -0.639361
# CPI                                                        -0.681109
# temperature                                                -0.645303
#
#                                         IPI  construction_value       CPI  \
# year                              -0.728703            0.934051  0.714266
# week                               0.081299            0.269128  0.527370
# month                              0.107030            0.268547  0.529914
# sales                              0.066981           -0.036542 -0.040313
# Public                            -0.279005            0.602598  0.245650
# Private                           -0.785831            0.993005  0.831945
# Total                             -0.764314            1.000000  0.802367
# overall_unemployment_rate          0.533907           -0.922206 -0.711763
# labor_force                       -0.676298            0.931756  0.827945
# employment                        -0.641426            0.961232  0.809087
# unemployment                       0.521139           -0.914858 -0.698456
# workforce_in_construction         -0.638875            0.967741  0.787054
# unemployment_rate_in_construction  0.235538           -0.639361 -0.681109
# IPI                                1.000000           -0.764314 -0.535250
# construction_value                -0.764314            1.000000  0.802367
# CPI                               -0.535250            0.802367  1.000000
# temperature                        0.073937            0.050115  0.231703
#
#                                    temperature
# year                                 -0.003053
# week                                  0.246686
# month                                 0.225934
# sales                                 0.009692
# Public                                0.137858
# Private                               0.033837
# Total                                 0.050115
# overall_unemployment_rate            -0.063233
# labor_force                           0.020080
# employment                            0.044072
# unemployment                         -0.079231
# workforce_in_construction             0.048973
# unemployment_rate_in_construction    -0.645303
# IPI                                   0.073937
# construction_value                    0.050115
# CPI                                   0.231703
# temperature                           1.000000

# %% [markdown]
# analysis

# %%
from sklearn import datasets, linear_model

# %%
week.columns
# Out:
# Index(['year', 'week', 'month', 'sales', 'Date', 'Public', 'Private', 'Total',
#        'month str', 'overall_unemployment_rate', 'labor_force', 'employment',
#        'unemployment', 'workforce_in_construction',
#        'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
#        'temperature'],
#       dtype='object')

# %%
week = week.sort(['year', 'month', 'week'])
week.head(5)
# Out:
# D:\anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    year  week  month         sales       Date  Public  Private   Total  \
# 0  2014     1      1  4.912439e+06 2014-01-01  260580   694062  954642
# 2  2014     2      1  1.450659e+07 2014-01-01  260580   694062  954642
# 3  2014     3      1  1.740329e+07 2014-01-01  260580   694062  954642
# 4  2014     4      1  1.610537e+07 2014-01-01  260580   694062  954642
# 5  2014     5      1  1.839390e+07 2014-01-01  260580   694062  954642
#
#   month str  overall_unemployment_rate  labor_force  employment  unemployment  \
# 0   January                        6.6       155295      145055         10240
# 2   January                        6.6       155295      145055         10240
# 3   January                        6.6       155295      145055         10240
# 4   January                        6.6       155295      145055         10240
# 5   January                        6.6       155295      145055         10240
#
#    workforce_in_construction  unemployment_rate_in_construction       IPI  \
# 0                       5989                               12.3  102.6063
# 2                       5989                               12.3  102.6063
# 3                       5989                               12.3  102.6063
# 4                       5989                               12.3  102.6063
# 5                       5989                               12.3  102.6063
#
#    construction_value      CPI  temperature
# 0              954642  235.385         31.9
# 2              954642  235.385         31.9
# 3              954642  235.385         31.9
# 4              954642  235.385         31.9
# 5              954642  235.385         31.9

# %%
x = week[['year', 'week', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = week['sales']
def machinelearning(x,y,i):
    xtrain = x[:i]
    ytrain = y[:i]
    xtest = x[i:i+10]
    ytest = y[i:i+10]
    print(xtrain.shape, ytrain.shape)
    #print(ytest)
    reg = linear_model.LinearRegression()
    reg.fit(xtrain,ytrain)
    # The coefficients
    # print('Coefficients:', reg.coef_)
    # The mean squared error
    print("Mean squared error: %.2f"
          % np.mean((reg.predict(xtest) - ytest) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % reg.score(xtest, ytest))
    a = list(reg.predict(xtest))
    b = list(ytest)
    plt.figure(figsize=(8,1))
    plt.plot(a,color='r')
    plt.plot(b)
    plt.show()

for i in range(115,130):
    machinelearning(x,y,i)
# Out:
# (115, 16) (115,)
# Mean squared error: 9648251426191.95
# Variance score: -0.31
# (116, 16) (116,)
# Mean squared error: 20298536457199.10
# Variance score: -0.18
# (117, 16) (117,)
# Mean squared error: 18021237943546.67
# Variance score: -0.09
# (118, 16) (118,)
# Mean squared error: 20068003797083.76
# Variance score: -0.16
# (119, 16) (119,)
# Mean squared error: 25179795369781.52
# Variance score: -0.30
# (120, 16) (120,)
# Mean squared error: 25049321964953.38
# Variance score: -0.29
# (121, 16) (121,)
# Mean squared error: 25066786286528.66
# Variance score: -0.29
# (122, 16) (122,)
# Mean squared error: 52603383993356.98
# Variance score: -0.31
# (123, 16) (123,)
# Mean squared error: 53365897556698.88
# Variance score: -0.24
# (124, 16) (124,)
# Mean squared error: 53268055320031.40
# Variance score: -0.24
# (125, 16) (125,)
# Mean squared error: 53660535948279.96
# Variance score: -0.23
# (126, 16) (126,)
# Mean squared error: 41167729316043.27
# Variance score: -0.30
# (127, 16) (127,)
# Mean squared error: 40040696566882.66
# Variance score: -0.23
# (128, 16) (128,)
# Mean squared error: 34922683232388.59
# Variance score: -0.07
# (129, 16) (129,)
# Mean squared error: 32155683657432.36
# Variance score: -0.05

# %%
week = week.sort(['year', 'month', 'week'])
week.head(5)
# Out:
# D:\anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    year  week  month         sales       Date  Public  Private   Total  \
# 0  2014     1      1  4.912439e+06 2014-01-01  260580   694062  954642
# 2  2014     2      1  1.450659e+07 2014-01-01  260580   694062  954642
# 3  2014     3      1  1.740329e+07 2014-01-01  260580   694062  954642
# 4  2014     4      1  1.610537e+07 2014-01-01  260580   694062  954642
# 5  2014     5      1  1.839390e+07 2014-01-01  260580   694062  954642
#
#   month str  overall_unemployment_rate  labor_force  employment  unemployment  \
# 0   January                        6.6       155295      145055         10240
# 2   January                        6.6       155295      145055         10240
# 3   January                        6.6       155295      145055         10240
# 4   January                        6.6       155295      145055         10240
# 5   January                        6.6       155295      145055         10240
#
#    workforce_in_construction  unemployment_rate_in_construction       IPI  \
# 0                       5989                               12.3  102.6063
# 2                       5989                               12.3  102.6063
# 3                       5989                               12.3  102.6063
# 4                       5989                               12.3  102.6063
# 5                       5989                               12.3  102.6063
#
#    construction_value      CPI  temperature
# 0              954642  235.385         31.9
# 2              954642  235.385         31.9
# 3              954642  235.385         31.9
# 4              954642  235.385         31.9
# 5              954642  235.385         31.9

# %%
x = week[['year', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = week['sales']
xtrain = x[:-52]
ytrain = y[:-52]
xtest = x[-52:]
ytest = y[-52:]
print( xtrain.shape, ytrain.shape)
reg = linear_model.LinearRegression()
reg.fit(xtrain,ytrain)
# The coefficients
print('Coefficients:', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((reg.predict(xtest) - ytest) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % reg.score(xtest, ytest))
a = list(reg.predict(xtest))
b = list(ytest)
plt.plot(a,color='r')
plt.plot(b)
plt.show()
# Out:
# (124, 15) (124,)
# Coefficients: [  2.77368958e+07   2.17357086e+06   4.53004104e+01  -5.98778772e+01
#   -1.45773449e+01  -7.90092453e+06   9.91598968e+05  -9.90504924e+05
#   -9.86458944e+05  -7.88780297e+04   5.85504028e+04  -4.43899390e+05
#   -1.45773287e+01   1.91811568e+06  -6.56927001e+04]
# Mean squared error: 175096204656299.84
# Variance score: -4.78

# %%
month.columns
# Out:
# Index(['year', 'month', 'sales', 'Public', 'Private', 'Total',
#        'overall_unemployment_rate', 'labor_force', 'employment',
#        'unemployment', 'workforce_in_construction',
#        'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
#        'temperature'],
#       dtype='object')

# %%
month.shape
# Out:
# (36, 16)

# %%
month = month.sort(['year', 'month'])
month
# Out:
# D:\anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     year  month         sales  Public  Private    Total  \
# 0   2014      1  7.132159e+07  260580   694062   954642
# 1   2014      2  7.045462e+07  260887   686201   947088
# 2   2014      3  7.934422e+07  264972   682331   947303
# 3   2014      4  7.823823e+07  270530   684588   955118
# 4   2014      5  7.699178e+07  273317   682820   956137
# 5   2014      6  8.014754e+07  272854   684266   957120
# 6   2014      7  7.759557e+07  277224   682819   960043
# 7   2014      8  7.796993e+07  276685   684382   961067
# 8   2014      9  7.939032e+07  272291   688027   960318
# 9   2014     10  9.052564e+07  278593   692396   970989
# 10  2014     11  7.028595e+07  276371   697930   974301
# 11  2014     12  8.059821e+07  280019   704483   984502
# 12  2015      1  7.618155e+07  270982   696948   967930
# 13  2015      2  7.308348e+07  268933   698237   967170
# 14  2015      3  8.957937e+07  276638   729713  1006351
# 15  2015      4  7.876214e+07  287432   757209  1044641
# 16  2015      5  7.548679e+07  293503   769989  1063492
# 17  2015      6  8.425452e+07  298228   766366  1064594
# 18  2015      7  8.616322e+07  299109   781249  1080358
# 19  2015      8  8.197954e+07  301103   788698  1089801
# 20  2015      9  8.745651e+07  300797   795841  1096638
# 21  2015     10  8.097267e+07  304946   802435  1107381
# 22  2015     11  7.667062e+07  286768   830195  1116963
# 23  2015     12  7.452400e+07  296153   827345  1123498
# 24  2016      1  6.889580e+07  295186   849743  1144929
# 25  2016      2  7.376702e+07  299567   858137  1157704
# 26  2016      3  8.608174e+07  297390   878990  1176380
# 27  2016      4  7.434480e+07  290510   861853  1152363
# 28  2016      5  7.848522e+07  283951   859306  1143257
# 29  2016      6  8.264176e+07  286193   867941  1154134
# 30  2016      7  6.832706e+07  275556   884852  1160408
# 31  2016      8  8.615605e+07  272836   881552  1154388
# 32  2016      9  7.895469e+07  270346   879660  1150006
# 33  2016     10  8.102443e+07  287577   886172  1173749
# 34  2016     11  7.781063e+07  286761   904708  1191469
# 35  2016     12  7.407505e+07  282763   909387  1192150
#
#     overall_unemployment_rate  labor_force  employment  unemployment  \
# 0                         6.6       155295      145055         10240
# 1                         6.7       155485      145102         10383
# 2                         6.7       156115      145715         10400
# 3                         6.2       155378      145673          9705
# 4                         6.3       155559      145819          9740
# 5                         6.1       155682      146222          9460
# 6                         6.2       156098      146461          9637
# 7                         6.2       156117      146501          9616
# 8                         5.9       156100      146845          9255
# 9                         5.7       156389      147426          8964
# 10                        5.8       156421      147361          9060
# 11                        5.6       156238      147521          8718
# 12                        5.7       157022      148061          8962
# 13                        5.5       156771      148108          8663
# 14                        5.4       156781      148244          8538
# 15                        5.4       157043      148522          8521
# 16                        5.5       157447      148792          8655
# 17                        5.3       156993      148742          8251
# 18                        5.2       157125      148890          8235
# 19                        5.1       157109      149092          8017
# 20                        5.0       156809      148932          7877
# 21                        5.0       157123      149255          7869
# 22                        5.0       157358      149419          7939
# 23                        5.0       157957      150030          7927
# 24                        4.9       158362      150533          7829
# 25                        4.9       158888      151043          7845
# 26                        5.0       159278      151301          7977
# 27                        5.0       158938      151028          7910
# 28                        4.7       158510      151058          7451
# 29                        4.9       158889      151090          7799
# 30                        4.9       159295      151546          7749
# 31                        4.9       159508      151655          7853
# 32                        4.9       159830      151926          7904
# 33                        4.8       159643      151902          7740
# 34                        4.6       159456      152048          7409
# 35                        4.7       159640      152111          7529
#
#     workforce_in_construction  unemployment_rate_in_construction       IPI  \
# 0                        5989                               12.3  102.6063
# 1                        6010                               12.8  103.6292
# 2                        6047                               11.3  104.5546
# 3                        6086                                9.4  104.7807
# 4                        6112                                8.6  105.0799
# 5                        6132                                8.2  105.4698
# 6                        6174                                7.5  105.4919
# 7                        6204                                7.7  105.4250
# 8                        6231                                7.0  105.7329
# 9                        6251                                6.4  105.7898
# 10                       6269                                7.5  106.6134
# 11                       6292                                8.3  106.3797
# 12                       6336                                9.8  105.6148
# 13                       6362                               10.6  105.4321
# 14                       6351                                9.5  105.0745
# 15                       6395                                7.5  104.6624
# 16                       6432                                6.7  104.2843
# 17                       6446                                6.3  103.9927
# 18                       6467                                5.5  104.5150
# 19                       6482                                6.1  104.5091
# 20                       6490                                5.5  104.2038
# 21                       6534                                6.2  104.0045
# 22                       6589                                6.2  103.3965
# 23                       6628                                7.5  102.9179
# 24                       6639                                8.5  103.4822
# 25                       6662                                8.7  103.2685
# 26                       6705                                8.7  102.5263
# 27                       6704                                6.0  102.8697
# 28                       6690                                5.2  102.7552
# 29                       6690                                4.6  103.1249
# 30                       6708                                4.5  103.2173
# 31                       6704                                5.1  103.1459
# 32                       6727                                5.2  102.9898
# 33                       6743                                5.7  103.2162
# 34                       6771                                5.7  103.0300
# 35                       6783                                7.4  103.7574
#
#     construction_value      CPI  temperature
# 0               954642  235.385         31.9
# 1               947088  235.672         35.3
# 2               947303  235.978         42.4
# 3               955118  236.471         52.0
# 4               956137  236.832         60.8
# 5               957120  237.029         68.7
# 6               960043  237.424         73.3
# 7               961067  237.256         72.1
# 8               960318  237.486         65.2
# 9               970989  237.506         54.8
# 10              974301  237.118         43.5
# 11              984502  236.290         34.5
# 12              967930  234.913         31.9
# 13              967170  235.489         35.3
# 14             1006351  235.989         42.4
# 15             1044641  236.201         52.0
# 16             1063492  236.891         60.8
# 17             1064594  237.419         68.7
# 18             1080358  237.876         73.3
# 19             1089801  237.811         72.1
# 20             1096638  237.467         65.2
# 21             1107381  237.792         54.8
# 22             1116963  238.153         43.5
# 23             1123498  237.846         34.5
# 24             1144929  238.106         31.9
# 25             1157704  237.808         35.3
# 26             1176380  238.078         42.4
# 27             1152363  238.908         52.0
# 28             1143257  239.362         60.8
# 29             1154134  239.842         68.7
# 30             1160408  239.898         73.3
# 31             1154388  240.389         72.1
# 32             1150006  241.006         65.2
# 33             1173749  241.694         54.8
# 34             1191469  242.199         43.5
# 35             1192150  242.821         34.5

# %%
x = month[['year', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = month['sales']
xtrain = x[:-12]
ytrain = y[:-12]
xtest = x[-12:]
ytest = y[-12:]
print( xtrain.shape, ytrain.shape)
reg = linear_model.LinearRegression()
reg.fit(xtrain,ytrain)
# The coefficients
print('Coefficients:', reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((reg.predict(xtest) - ytest) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % reg.score(xtest, ytest))
plt.plot(list(reg.predict(xtest)), color = 'r')
plt.plot(list(ytest))
plt.show()
# Out:
# (24, 15) (24,)
# Coefficients: [  4.25395360e+07   3.98994609e+06  -6.79626637e+14  -6.79626637e+14
#    3.39817090e+14  -3.52263616e+07  -6.54305553e+06   6.55228165e+06
#    6.56196706e+06  -2.03098266e+05  -5.42577430e+05  -3.07916222e+06
#    3.39809547e+14   2.67318242e+05   3.00640875e+05]
# Mean squared error: 606364797362658.00
# Variance score: -17.93

# %%
for i in range(18,26):
    machinelearning(x,y,i)
# Out:
# (18, 15) (18,)
# Mean squared error: 264110615822836.81
# Variance score: -6.29
# (19, 15) (19,)
# Mean squared error: 287256517925001.62
# Variance score: -8.37
# (20, 15) (20,)
# Mean squared error: 506993393669115.31
# Variance score: -15.26
# (21, 15) (21,)
# Mean squared error: 468346199899373.19
# Variance score: -14.92
# (22, 15) (22,)
# Mean squared error: 825422069976142.50
# Variance score: -21.62
# (23, 15) (23,)
# Mean squared error: 632922618671889.12
# Variance score: -16.19
# (24, 15) (24,)
# Mean squared error: 522016490923557.62
# Variance score: -13.06
# (25, 15) (25,)
# Mean squared error: 592406414085042.62
# Variance score: -19.95

# %%
data
# Out:
#       BILL_RUN_DATE  year month_nm Division         sales  dayofweek  week  \
# 0        2014-01-03  2014      Jan        C  2.527858e+06          4     1
# 1        2014-01-03  2014      Jan        S  8.450965e+04          4     1
# 2        2014-01-03  2014      Jan        G  1.027920e+03          4     1
# 3        2014-01-03  2014      Jan        F  2.113662e+03          4     1
# 4        2014-01-03  2014      Jan        K  3.411432e+05          4     1
# 5        2014-01-03  2014      Jan        B  8.391750e+03          4     1
# 6        2014-01-03  2014      Jan        P  3.837473e+04          4     1
# 7        2014-01-03  2014      Jan        A  2.074950e+03          4     1
# 8        2014-01-03  2014      Jan        Q  4.920000e+02          4     1
# 9        2014-01-03  2014      Jan       AA  0.000000e+00          4     1
# 10       2014-01-03  2014      Jan        D  1.440014e+04          4     1
# 11       2014-01-03  2014      Jan        O  2.480308e+05          4     1
# 12       2014-01-03  2014      Jan        R  1.026249e+06          4     1
# 13       2014-01-03  2014      Jan        N  8.283583e+04          4     1
# 14       2014-01-03  2014      Jan        M  1.948602e+04          4     1
# 15       2014-01-03  2014      Jan       BB  0.000000e+00          4     1
# 16       2014-01-03  2014      Jan        U  5.321178e+03          4     1
# 17       2014-01-03  2014      Jan        E  8.202200e+04          4     1
# 18       2014-01-03  2014      Jan        H  2.073676e+05          4     1
# 19       2014-01-03  2014      Jan        I  1.729344e+03          4     1
# 20       2014-01-03  2014      Jan        J  8.196100e+04          4     1
# 21       2014-01-03  2014      Jan        J  3.057955e+04          4     1
# 22       2014-01-06  2014      Jan        N  8.364701e+04          0     2
# 23       2014-01-06  2014      Jan        U  2.784660e+03          0     2
# 24       2014-01-06  2014      Jan        I  1.121316e+03          0     2
# 25       2014-01-06  2014      Jan        E  1.350000e+02          0     2
# 26       2014-01-06  2014      Jan        M  8.583204e+03          0     2
# 27       2014-01-06  2014      Jan        H  2.104955e+05          0     2
# 28       2014-01-06  2014      Jan        C  1.364967e+06          0     2
# 29       2014-01-06  2014      Jan        F  2.441160e+02          0     2
# ...             ...   ...      ...      ...           ...        ...   ...
# 17058    2016-12-30  2016      Dec        B  1.706899e+04          4    52
# 17059    2016-12-30  2016      Dec        O  1.044047e+05          4    52
# 17060    2016-12-30  2016      Dec        N  5.093336e+04          4    52
# 17061    2016-12-30  2016      Dec       AA  0.000000e+00          4    52
# 17062    2016-12-30  2016      Dec        U  1.559916e+03          4    52
# 17063    2016-12-30  2016      Dec        M  1.654962e+03          4    52
# 17064    2016-12-30  2016      Dec        C  1.245113e+06          4    52
# 17065    2016-12-30  2016      Dec        E -1.318199e+04          4    52
# 17066    2016-12-30  2016      Dec        H  6.406255e+04          4    52
# 17067    2016-12-30  2016      Dec        I  4.055652e+03          4    52
# 17068    2016-12-30  2016      Dec        L  3.103920e+04          4    52
# 17069    2016-12-30  2016      Dec        S  1.291194e+05          4    52
# 17070    2016-12-30  2016      Dec        F  6.948000e+01          4    52
# 17071    2016-12-30  2016      Dec        K  2.713549e+05          4    52
# 17072    2017-01-03  2016      Dec        H  6.402096e+03          1     1
# 17073    2017-01-03  2016      Dec        C  3.136731e+05          1     1
# 17074    2017-01-03  2016      Dec        S  2.703763e+04          1     1
# 17075    2017-01-03  2016      Dec        J  1.801692e+03          1     1
# 17076    2017-01-03  2016      Dec        A  8.638602e+03          1     1
# 17077    2017-01-03  2016      Dec        P  3.583368e+03          1     1
# 17078    2017-01-03  2016      Dec        B  5.308830e+03          1     1
# 17079    2017-01-03  2016      Dec        R  3.679597e+04          1     1
# 17080    2017-01-03  2016      Dec        I  2.407536e+03          1     1
# 17081    2017-01-03  2016      Dec        U  2.164320e+02          1     1
# 17082    2017-01-03  2016      Dec        N  1.221898e+04          1     1
# 17083    2017-01-03  2016      Dec       AA  0.000000e+00          1     1
# 17084    2017-01-03  2016      Dec        O  2.215374e+03          1     1
# 17085    2017-01-03  2016      Dec        K  1.839684e+05          1     1
# 17086    2017-01-03  2016      Dec        O  1.953330e+03          1     1
# 17087    2017-01-03  2016      Dec        K  1.757920e+05          1     1
#
#        month       Date  Public     ...       overall_unemployment_rate  \
# 0          1 2014-01-01  260580     ...                             6.6
# 1          1 2014-01-01  260580     ...                             6.6
# 2          1 2014-01-01  260580     ...                             6.6
# 3          1 2014-01-01  260580     ...                             6.6
# 4          1 2014-01-01  260580     ...                             6.6
# 5          1 2014-01-01  260580     ...                             6.6
# 6          1 2014-01-01  260580     ...                             6.6
# 7          1 2014-01-01  260580     ...                             6.6
# 8          1 2014-01-01  260580     ...                             6.6
# 9          1 2014-01-01  260580     ...                             6.6
# 10         1 2014-01-01  260580     ...                             6.6
# 11         1 2014-01-01  260580     ...                             6.6
# 12         1 2014-01-01  260580     ...                             6.6
# 13         1 2014-01-01  260580     ...                             6.6
# 14         1 2014-01-01  260580     ...                             6.6
# 15         1 2014-01-01  260580     ...                             6.6
# 16         1 2014-01-01  260580     ...                             6.6
# 17         1 2014-01-01  260580     ...                             6.6
# 18         1 2014-01-01  260580     ...                             6.6
# 19         1 2014-01-01  260580     ...                             6.6
# 20         1 2014-01-01  260580     ...                             6.6
# 21         1 2014-01-01  260580     ...                             6.6
# 22         1 2014-01-01  260580     ...                             6.6
# 23         1 2014-01-01  260580     ...                             6.6
# 24         1 2014-01-01  260580     ...                             6.6
# 25         1 2014-01-01  260580     ...                             6.6
# 26         1 2014-01-01  260580     ...                             6.6
# 27         1 2014-01-01  260580     ...                             6.6
# 28         1 2014-01-01  260580     ...                             6.6
# 29         1 2014-01-01  260580     ...                             6.6
# ...      ...        ...     ...     ...                             ...
# 17058     12 2016-12-01  282763     ...                             4.7
# 17059     12 2016-12-01  282763     ...                             4.7
# 17060     12 2016-12-01  282763     ...                             4.7
# 17061     12 2016-12-01  282763     ...                             4.7
# 17062     12 2016-12-01  282763     ...                             4.7
# 17063     12 2016-12-01  282763     ...                             4.7
# 17064     12 2016-12-01  282763     ...                             4.7
# 17065     12 2016-12-01  282763     ...                             4.7
# 17066     12 2016-12-01  282763     ...                             4.7
# 17067     12 2016-12-01  282763     ...                             4.7
# 17068     12 2016-12-01  282763     ...                             4.7
# 17069     12 2016-12-01  282763     ...                             4.7
# 17070     12 2016-12-01  282763     ...                             4.7
# 17071     12 2016-12-01  282763     ...                             4.7
# 17072      1 2016-01-01  295186     ...                             4.9
# 17073      1 2016-01-01  295186     ...                             4.9
# 17074      1 2016-01-01  295186     ...                             4.9
# 17075      1 2016-01-01  295186     ...                             4.9
# 17076      1 2016-01-01  295186     ...                             4.9
# 17077      1 2016-01-01  295186     ...                             4.9
# 17078      1 2016-01-01  295186     ...                             4.9
# 17079      1 2016-01-01  295186     ...                             4.9
# 17080      1 2016-01-01  295186     ...                             4.9
# 17081      1 2016-01-01  295186     ...                             4.9
# 17082      1 2016-01-01  295186     ...                             4.9
# 17083      1 2016-01-01  295186     ...                             4.9
# 17084      1 2016-01-01  295186     ...                             4.9
# 17085      1 2016-01-01  295186     ...                             4.9
# 17086      1 2016-01-01  295186     ...                             4.9
# 17087      1 2016-01-01  295186     ...                             4.9
#
#        labor_force employment  unemployment  workforce_in_construction  \
# 0           155295     145055         10240                       5989
# 1           155295     145055         10240                       5989
# 2           155295     145055         10240                       5989
# 3           155295     145055         10240                       5989
# 4           155295     145055         10240                       5989
# 5           155295     145055         10240                       5989
# 6           155295     145055         10240                       5989
# 7           155295     145055         10240                       5989
# 8           155295     145055         10240                       5989
# 9           155295     145055         10240                       5989
# 10          155295     145055         10240                       5989
# 11          155295     145055         10240                       5989
# 12          155295     145055         10240                       5989
# 13          155295     145055         10240                       5989
# 14          155295     145055         10240                       5989
# 15          155295     145055         10240                       5989
# 16          155295     145055         10240                       5989
# 17          155295     145055         10240                       5989
# 18          155295     145055         10240                       5989
# 19          155295     145055         10240                       5989
# 20          155295     145055         10240                       5989
# 21          155295     145055         10240                       5989
# 22          155295     145055         10240                       5989
# 23          155295     145055         10240                       5989
# 24          155295     145055         10240                       5989
# 25          155295     145055         10240                       5989
# 26          155295     145055         10240                       5989
# 27          155295     145055         10240                       5989
# 28          155295     145055         10240                       5989
# 29          155295     145055         10240                       5989
# ...            ...        ...           ...                        ...
# 17058       159640     152111          7529                       6783
# 17059       159640     152111          7529                       6783
# 17060       159640     152111          7529                       6783
# 17061       159640     152111          7529                       6783
# 17062       159640     152111          7529                       6783
# 17063       159640     152111          7529                       6783
# 17064       159640     152111          7529                       6783
# 17065       159640     152111          7529                       6783
# 17066       159640     152111          7529                       6783
# 17067       159640     152111          7529                       6783
# 17068       159640     152111          7529                       6783
# 17069       159640     152111          7529                       6783
# 17070       159640     152111          7529                       6783
# 17071       159640     152111          7529                       6783
# 17072       158362     150533          7829                       6639
# 17073       158362     150533          7829                       6639
# 17074       158362     150533          7829                       6639
# 17075       158362     150533          7829                       6639
# 17076       158362     150533          7829                       6639
# 17077       158362     150533          7829                       6639
# 17078       158362     150533          7829                       6639
# 17079       158362     150533          7829                       6639
# 17080       158362     150533          7829                       6639
# 17081       158362     150533          7829                       6639
# 17082       158362     150533          7829                       6639
# 17083       158362     150533          7829                       6639
# 17084       158362     150533          7829                       6639
# 17085       158362     150533          7829                       6639
# 17086       158362     150533          7829                       6639
# 17087       158362     150533          7829                       6639
#
#        unemployment_rate_in_construction       IPI  construction_value  \
# 0                                   12.3  102.6063              954642
# 1                                   12.3  102.6063              954642
# 2                                   12.3  102.6063              954642
# 3                                   12.3  102.6063              954642
# 4                                   12.3  102.6063              954642
# 5                                   12.3  102.6063              954642
# 6                                   12.3  102.6063              954642
# 7                                   12.3  102.6063              954642
# 8                                   12.3  102.6063              954642
# 9                                   12.3  102.6063              954642
# 10                                  12.3  102.6063              954642
# 11                                  12.3  102.6063              954642
# 12                                  12.3  102.6063              954642
# 13                                  12.3  102.6063              954642
# 14                                  12.3  102.6063              954642
# 15                                  12.3  102.6063              954642
# 16                                  12.3  102.6063              954642
# 17                                  12.3  102.6063              954642
# 18                                  12.3  102.6063              954642
# 19                                  12.3  102.6063              954642
# 20                                  12.3  102.6063              954642
# 21                                  12.3  102.6063              954642
# 22                                  12.3  102.6063              954642
# 23                                  12.3  102.6063              954642
# 24                                  12.3  102.6063              954642
# 25                                  12.3  102.6063              954642
# 26                                  12.3  102.6063              954642
# 27                                  12.3  102.6063              954642
# 28                                  12.3  102.6063              954642
# 29                                  12.3  102.6063              954642
# ...                                  ...       ...                 ...
# 17058                                7.4  103.7574             1192150
# 17059                                7.4  103.7574             1192150
# 17060                                7.4  103.7574             1192150
# 17061                                7.4  103.7574             1192150
# 17062                                7.4  103.7574             1192150
# 17063                                7.4  103.7574             1192150
# 17064                                7.4  103.7574             1192150
# 17065                                7.4  103.7574             1192150
# 17066                                7.4  103.7574             1192150
# 17067                                7.4  103.7574             1192150
# 17068                                7.4  103.7574             1192150
# 17069                                7.4  103.7574             1192150
# 17070                                7.4  103.7574             1192150
# 17071                                7.4  103.7574             1192150
# 17072                                8.5  103.4822             1144929
# 17073                                8.5  103.4822             1144929
# 17074                                8.5  103.4822             1144929
# 17075                                8.5  103.4822             1144929
# 17076                                8.5  103.4822             1144929
# 17077                                8.5  103.4822             1144929
# 17078                                8.5  103.4822             1144929
# 17079                                8.5  103.4822             1144929
# 17080                                8.5  103.4822             1144929
# 17081                                8.5  103.4822             1144929
# 17082                                8.5  103.4822             1144929
# 17083                                8.5  103.4822             1144929
# 17084                                8.5  103.4822             1144929
# 17085                                8.5  103.4822             1144929
# 17086                                8.5  103.4822             1144929
# 17087                                8.5  103.4822             1144929
#
#            CPI  temperature
# 0      235.385         31.9
# 1      235.385         31.9
# 2      235.385         31.9
# 3      235.385         31.9
# 4      235.385         31.9
# 5      235.385         31.9
# 6      235.385         31.9
# 7      235.385         31.9
# 8      235.385         31.9
# 9      235.385         31.9
# 10     235.385         31.9
# 11     235.385         31.9
# 12     235.385         31.9
# 13     235.385         31.9
# 14     235.385         31.9
# 15     235.385         31.9
# 16     235.385         31.9
# 17     235.385         31.9
# 18     235.385         31.9
# 19     235.385         31.9
# 20     235.385         31.9
# 21     235.385         31.9
# 22     235.385         31.9
# 23     235.385         31.9
# 24     235.385         31.9
# 25     235.385         31.9
# 26     235.385         31.9
# 27     235.385         31.9
# 28     235.385         31.9
# 29     235.385         31.9
# ...        ...          ...
# 17058  242.821         34.5
# 17059  242.821         34.5
# 17060  242.821         34.5
# 17061  242.821         34.5
# 17062  242.821         34.5
# 17063  242.821         34.5
# 17064  242.821         34.5
# 17065  242.821         34.5
# 17066  242.821         34.5
# 17067  242.821         34.5
# 17068  242.821         34.5
# 17069  242.821         34.5
# 17070  242.821         34.5
# 17071  242.821         34.5
# 17072  238.106         31.9
# 17073  238.106         31.9
# 17074  238.106         31.9
# 17075  238.106         31.9
# 17076  238.106         31.9
# 17077  238.106         31.9
# 17078  238.106         31.9
# 17079  238.106         31.9
# 17080  238.106         31.9
# 17081  238.106         31.9
# 17082  238.106         31.9
# 17083  238.106         31.9
# 17084  238.106         31.9
# 17085  238.106         31.9
# 17086  238.106         31.9
# 17087  238.106         31.9
#
# [17088 rows x 23 columns]

# %%
cluster1st = ['C','K','N','O','R']
cluster2nd = ['H','J','S','E']
cluster1 = data.loc[data['Division'].isin(cluster1st)]
cluster2 = data.loc[data['Division'].isin(cluster2nd)]
cluster3 = data.loc[~data['Division'].isin(cluster2nd+cluster1st)]

# %%
cluster1week = cluster1.groupby(['year','week','month'],as_index=False)['sales'].sum()
cluster1week = pd.merge(cluster1week, data2, on = ['month','year'], how = 'left')
cluster1week = pd.merge(cluster1week, data1, on = ['month','year'], how = 'left')
#week = data.groupby(['year','week'],as_index=False)['sales'].sum()
#del week['Date']
#del week['month str']
x = cluster1week[['year', 'week', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster1week['sales']
for i in range(100,120,4):
    machinelearning(x,y,i)
# Out:
# (100, 16) (100,)
# Mean squared error: 18193891775142.71
# Variance score: -0.25
# (104, 16) (104,)
# Mean squared error: 31510446008258.43
# Variance score: -1.09
# (108, 16) (108,)
# Mean squared error: 33180975951886.43
# Variance score: -1.31
# (112, 16) (112,)
# Mean squared error: 7526388755076.53
# Variance score: -0.10
# (116, 16) (116,)
# Mean squared error: 16065383744764.71
# Variance score: -0.20

# %%
cluster2week = cluster2.groupby(['year','week','month'],as_index=False)['sales'].sum()
cluster2week = pd.merge(cluster2week, data2, on = ['month','year'], how = 'left')
cluster2week = pd.merge(cluster2week, data1, on = ['month','year'], how = 'left')
#week = data.groupby(['year','week'],as_index=False)['sales'].sum()
#del week['Date']
#del week['month str']
x = cluster2week[['year', 'week', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster2week['sales']
for i in range(100,120,4):
    machinelearning(x,y,i)
# Out:
# (100, 16) (100,)
# Mean squared error: 649240652129.70
# Variance score: -2.59
# (104, 16) (104,)
# Mean squared error: 1107132794917.88
# Variance score: -4.05
# (108, 16) (108,)
# Mean squared error: 527898170239.83
# Variance score: -0.83
# (112, 16) (112,)
# Mean squared error: 190884141452.23
# Variance score: -0.07
# (116, 16) (116,)
# Mean squared error: 246155966459.01
# Variance score: -0.04

# %%
cluster3week = cluster3.groupby(['year','week','month'],as_index=False)['sales'].sum()
cluster3week = pd.merge(cluster3week, data2, on = ['month','year'], how = 'left')
cluster3week = pd.merge(cluster3week, data1, on = ['month','year'], how = 'left')
#week = data.groupby(['year','week'],as_index=False)['sales'].sum()
#del week['Date']
#del week['month str']
x = cluster3week[['year', 'week', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster3week['sales']
for i in range(100,120,4):
    machinelearning(x,y,i)
# Out:
# (100, 16) (100,)
# Mean squared error: 26383483499.03
# Variance score: -0.03
# (104, 16) (104,)
# Mean squared error: 54385500508.72
# Variance score: -0.53
# (108, 16) (108,)
# Mean squared error: 47379429845.69
# Variance score: -0.30
# (112, 16) (112,)
# Mean squared error: 20355310556.21
# Variance score: -0.96
# (116, 16) (116,)
# Mean squared error: 24399695692.96
# Variance score: -0.88

# %%
cluster1month = cluster1.groupby(['year', 'month'], as_index=False)['sales'].sum()

cluster1month = pd.merge(cluster1month, data2, on = ['month','year'], how = 'left')
cluster1month = pd.merge(cluster1month, data1, on = ['month','year'], how = 'left')
x = cluster1month[['year', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster1month['sales']
for i in range(16,26,4):
    machinelearning(x,y,i)
# Out:
# (16, 15) (16,)
# Mean squared error: 5308852510151090.00
# Variance score: -171.48
# (20, 15) (20,)
# Mean squared error: 242302131630182.31
# Variance score: -7.81
# (24, 15) (24,)
# Mean squared error: 532984892937903.50
# Variance score: -16.35

# %%
cluster2month = cluster2.groupby(['year', 'month'], as_index=False)['sales'].sum()

cluster2month = pd.merge(cluster2month, data2, on = ['month','year'], how = 'left')
cluster2month = pd.merge(cluster2month, data1, on = ['month','year'], how = 'left')
x = cluster2month[['year', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster2month['sales']
for i in range(16,26,4):
    machinelearning(x,y,i)
# Out:
# (16, 15) (16,)
# Mean squared error: 200641012110477.31
# Variance score: -1113.03
# (20, 15) (20,)
# Mean squared error: 53193174278002.61
# Variance score: -136.15
# (24, 15) (24,)
# Mean squared error: 1644193011749.86
# Variance score: -1.41

# %%
cluster3month = cluster3.groupby(['year', 'month'], as_index=False)['sales'].sum()

cluster3month = pd.merge(cluster3month, data2, on = ['month','year'], how = 'left')
cluster3month = pd.merge(cluster3month, data1, on = ['month','year'], how = 'left')
x = cluster3month[['year', 'month', 'Public', 'Private', 'Total',
       'overall_unemployment_rate', 'labor_force', 'employment',
       'unemployment', 'workforce_in_construction',
       'unemployment_rate_in_construction', 'IPI', 'construction_value', 'CPI',
       'temperature']]
y = cluster3month['sales']
for i in range(16,26,4):
    machinelearning(x,y,i)
# Out:
# (16, 15) (16,)
# Mean squared error: 964754456462.29
# Variance score: -23.35
# (20, 15) (20,)
# Mean squared error: 508839460190.33
# Variance score: -12.08
# (24, 15) (24,)
# Mean squared error: 644021513772.82
# Variance score: -19.45

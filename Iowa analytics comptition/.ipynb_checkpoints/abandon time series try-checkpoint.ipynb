# %%
# %pylab inline
import pandas as pd
import numpy as np
from scipy import  stats
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['table']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#PC 
data = pd.read_excel('C:/Users/Jeffery/Google Drive/Homework/IOWA/final data.xlsx')
#Mac data = pd.read_excel('/Users/Jeffery/Google Drive/Homework/IOWA/final data.xlsx')
data.head(5)
# Out:
#   BILL_RUN_DATE    yr month_nm Division        sales  dayofweek  week
# 0    2014-01-03  2014      Jan        C  2527858.254          4     1
# 1    2014-01-03  2014      Jan        S    84509.652          4     1
# 2    2014-01-03  2014      Jan        G     1027.920          4     1
# 3    2014-01-03  2014      Jan        F     2113.662          4     1
# 4    2014-01-03  2014      Jan        K   341143.206          4     1

# %%
devisiona = data.loc[data['Division'] == 'A']
backup = devisiona.loc[devisiona['yr'].isin([2016])]
devisiona = devisiona.loc[devisiona['yr'].isin([2014,2015])]
devisiona.head(5)
# Out:
#     BILL_RUN_DATE    yr month_nm Division     sales  dayofweek  week
# 7      2014-01-03  2014      Jan        A  2074.950          4     1
# 46     2014-01-07  2014      Jan        A   460.920          1     2
# 88     2014-01-09  2014      Jan        A  2431.338          3     2
# 109    2014-01-10  2014      Jan        A  4407.444          4     2
# 161    2014-01-14  2014      Jan        A  1193.664          1     3

# %%
devisiona = devisiona.groupby(['yr','week'],as_index = False).sum()
del devisiona['dayofweek']
devisiona
# Out:
#        yr  week         sales
# 0    2014     1   5724.294000
# 1    2014     2   7299.702000
# 2    2014     3  16901.508000
# 3    2014     4  11942.054542
# 4    2014     5  31720.890000
# 5    2014     6   2139.642000
# 6    2014     7  20599.044000
# 7    2014     8  17115.294326
# 8    2014     9  10440.240000
# 9    2014    10  11388.512657
# 10   2014    11   6622.572000
# 11   2014    12  -3553.740000
# 12   2014    13   2452.272000
# 13   2014    14   2474.034000
# 14   2014    15   5631.510000
# 15   2014    16  13937.052000
# 16   2014    17 -11578.608000
# 17   2014    18   4718.130000
# 18   2014    19   7029.857312
# 19   2014    20  14718.594000
# 20   2014    21  10877.610677
# 21   2014    22  -1718.922000
# 22   2014    23  11665.644000
# 23   2014    24   6571.269934
# 24   2014    25  12884.973973
# 25   2014    26  14001.552000
# 26   2014    27    581.998551
# 27   2014    28  10571.244276
# 28   2014    29   5348.388000
# 29   2014    30  -1351.434316
# ..    ...   ...           ...
# 74   2015    24  11342.448000
# 75   2015    25  17675.064000
# 76   2015    26  37176.363848
# 77   2015    27  24217.842000
# 78   2015    28  43336.386000
# 79   2015    29  40421.138720
# 80   2015    30  50813.306811
# 81   2015    31  54933.744000
# 82   2015    32  52384.034038
# 83   2015    33  40524.288000
# 84   2015    34  36765.216000
# 85   2015    35  70274.264708
# 86   2015    36  67284.127463
# 87   2015    37   8600.022000
# 88   2015    38  58535.490000
# 89   2015    39  19386.168000
# 90   2015    40  25356.978000
# 91   2015    41  24861.828000
# 92   2015    42  26129.325487
# 93   2015    43  -7307.784000
# 94   2015    44  50987.299683
# 95   2015    45  93806.824447
# 96   2015    46  87278.640000
# 97   2015    47  41937.059845
# 98   2015    48    137.520000
# 99   2015    49  56106.930353
# 100  2015    50  67414.208148
# 101  2015    51  30754.914925
# 102  2015    52  13312.080000
# 103  2015    53    356.520000
#
# [104 rows x 3 columns]

# %%
sales = pd.to_numeric(devisiona['sales'].as_matrix())
len(sales)
# Out:
# 104

# %%
dta = list(sales)
type(dta)
# Out:
# list

# %%
dta=pd.Series(dta)
dta.head(5)
# Out:
# 0     5724.294000
# 1     7299.702000
# 2    16901.508000
# 3    11942.054542
# 4    31720.890000
# dtype: float64

# %%
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('2001','2104'))
dta.head(5)
# Out:
# 2001-12-31     5724.294000
# 2002-12-31     7299.702000
# 2003-12-31    16901.508000
# 2004-12-31    11942.054542
# 2005-12-31    31720.890000
# dtype: float64

# %%
dta.plot(figsize=(12,8))

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(1)
diff1.plot(ax=ax1)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(2)
diff1.plot(ax=ax1)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(3)
diff1.plot(ax=ax1)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(4)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(4)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(5)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(6)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(7)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(8)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(9)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(10)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(11)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(12)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
dta= dta.diff(2)
dta = dta.dropna()
dta.head(2)
# Out:
# 2003-12-31    11177.214000
# 2004-12-31     4642.352542
# dtype: float64

# %%
#我们已经知道要使用一阶差分的时间序列，之前判断差分的程序可以注释掉
fig = plt.figure(figsize=(12,4))
ax1=fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta,lags=40,ax=ax2)

# %%
arma_mod20 = sm.tsa.ARMA(dta,(1,0)).fit()
print(arma_mod20.aic,arma_mod20.bic,arma_mod20.hqic)
arma_mod30 = sm.tsa.ARMA(dta,(2,0)).fit()
print(arma_mod30.aic,arma_mod30.bic,arma_mod30.hqic)
arma_mod40 = sm.tsa.ARMA(dta,(1,1)).fit()
print(arma_mod40.aic,arma_mod40.bic,arma_mod40.hqic)
arma_mod50 = sm.tsa.ARMA(dta,(2,1)).fit()
print(arma_mod50.aic,arma_mod50.bic,arma_mod50.hqic)
# Out:
# 2354.598943900929 2362.47386234 2357.78776686
# 2318.0321705557017 2328.53206181 2322.2839345
# D:\anaconda\lib\site-packages\statsmodels\base\model.py:473: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# 2322.9429119480965 2333.4428032 2327.19467589
# 2318.993338874057 2332.11820294 2324.3080438

# %%
resid = arma_mod30.resid
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=40, ax=ax2)

# %%
print(sm.stats.durbin_watson(arma_mod30.resid.values))
# Out:
# 2.03772764139

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid, line='q', ax=ax, fit=True)

# %%
r,q,p = sm.tsa.acf(resid.values.squeeze(), qstat=True)
data = np.c_[range(1,41), r[1:], q, p]
table = pd.DataFrame(data, columns=['lag', "AC", "Q", "Prob(>Q)"])
print(table.set_index('lag'))
# Out:
#             AC          Q  Prob(>Q)
# lag
# 1.0  -0.034645   0.126066  0.722546
# 2.0  -0.105985   1.317642  0.517461
# 3.0   0.055391   1.646403  0.648915
# 4.0  -0.209864   6.413824  0.170302
# 5.0   0.013628   6.434134  0.266237
# 6.0  -0.059075   6.819757  0.337838
# 7.0  -0.123598   8.525572  0.288535
# 8.0  -0.207652  13.391631  0.099066
# 9.0   0.113128  14.851414  0.095099
# 10.0  0.019096  14.893461  0.135995
# 11.0  0.040680  15.086372  0.178577
# 12.0 -0.040511  15.279805  0.226490
# 13.0  0.079564  16.034342  0.247280
# 14.0  0.063920  16.526855  0.282269
# 15.0 -0.049661  16.827566  0.329277
# 16.0  0.232370  23.487878  0.101302
# 17.0 -0.078619  24.259255  0.112560
# 18.0  0.013604  24.282627  0.145985
# 19.0  0.098177  25.514514  0.144294
# 20.0 -0.192926  30.329555  0.064687
# 21.0 -0.089770  31.384936  0.067486
# 22.0 -0.057046  31.816453  0.080580
# 23.0  0.022053  31.881759  0.102628
# 24.0 -0.033027  32.030106  0.126248
# 25.0 -0.106536  33.593750  0.116881
# 26.0  0.071890  34.315116  0.127273
# 27.0  0.032307  34.462739  0.153004
# 28.0  0.092186  35.680974  0.150903
# 29.0  0.083107  36.684633  0.154464
# 30.0  0.004216  36.687251  0.186432
# 31.0 -0.055175  37.142088  0.206892
# 32.0  0.052410  37.558342  0.229492
# 33.0 -0.019943  37.619490  0.265878
# 34.0 -0.151350  41.192959  0.184855
# 35.0  0.072347  42.021664  0.192851
# 36.0 -0.039868  42.277140  0.218205
# 37.0  0.012030  42.300757  0.252793
# 38.0  0.029134  42.441448  0.285451
# 39.0 -0.004743  42.445236  0.324841
# 40.0  0.005941  42.451274  0.365835

# %%
predict_sunspots = arma_mod30.predict('2104', '2112', dynamic=True)
print(predict_sunspots)
fig, ax = plt.subplots(figsize=(12, 3))
ax = dta.ix['2001':].plot(ax=ax)
predict_sunspots.plot(ax=ax)
# Out:
# 2104-12-31     3505.044166
# 2105-12-31    31935.435115
# 2106-12-31     4919.663539
# 2107-12-31   -16958.953205
# 2108-12-31    -6068.674581
# 2109-12-31     8706.947918
# 2110-12-31     5557.034483
# 2111-12-31    -3546.197265
# 2112-12-31    -3640.596426
# Freq: A-DEC, dtype: float64

# %%
dta['2104-12-31':]
# Out:
# 2104-12-31   -93450.304447
# dtype: float64

# %%
verify = backup.loc[backup['Division'] == 'A']
verify = verify.loc[verify['yr'].isin([2016])]
verify = verify.groupby(['yr','week'],as_index = False).sum()
sales = pd.to_numeric(verify['sales'].as_matrix())
sales = list(sales)
sales=pd.Series(sales)
sales.head(5)
# Out:
# 0     54040.536000
# 1    106144.698663
# 2     70121.970000
# 3     34272.834000
# 4     27666.624000
# dtype: float64

# %%
dta = list(sales)
dta=pd.Series(dta)
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('2104','2155'))
dta.head(5)
# Out:
# 2104-12-31     54040.536000
# 2105-12-31    106144.698663
# 2106-12-31     70121.970000
# 2107-12-31     34272.834000
# 2108-12-31     27666.624000
# dtype: float64

# %%
dta.diff(8)
# Out:
# 2104-12-31              NaN
# 2105-12-31              NaN
# 2106-12-31              NaN
# 2107-12-31              NaN
# 2108-12-31              NaN
# 2109-12-31              NaN
# 2110-12-31              NaN
# 2111-12-31              NaN
# 2112-12-31    -25893.324000
# 2113-12-31    -11890.056663
# 2114-12-31    -25457.370000
# 2115-12-31     55009.236000
# 2116-12-31    133529.412000
# 2117-12-31     34921.284114
# 2118-12-31    -86092.717780
# 2119-12-31     14125.543906
# 2120-12-31    -23978.742336
# 2121-12-31    -80762.985346
# 2122-12-31    -34802.022000
# 2123-12-31    -62288.772000
# 2124-12-31    -77884.198789
# 2125-12-31    -31901.646000
# 2126-12-31     76724.407780
# 2127-12-31     -6589.964953
# 2128-12-31     44208.522336
# 2129-12-31      6985.339553
# 2130-12-31     43595.568000
# 2131-12-31     18196.080000
# 2132-12-31    -45685.825211
# 2133-12-31     48163.548000
# 2134-12-31     24155.623352
# 2135-12-31      -891.052613
# 2136-12-31     24290.736000
# 2137-12-31     25268.275793
# 2138-12-31     -9734.262931
# 2139-12-31    -56698.119439
# 2140-12-31    122861.718000
# 2141-12-31    -82404.777658
# 2142-12-31     31118.812648
# 2143-12-31     88896.050557
# 2144-12-31     81254.028000
# 2145-12-31    115632.186000
# 2146-12-31    154424.944538
# 2147-12-31    208061.725542
# 2148-12-31     39428.910000
# 2149-12-31    253865.861895
# 2150-12-31     16769.634000
# 2151-12-31     55235.296087
# 2152-12-31      2866.848000
# 2153-12-31    -39058.566000
# 2154-12-31     41647.472543
# 2155-12-31    -54529.885363
# dtype: float64

# %%
fig = plt.figure(figsize=(12,2))
ax1= fig.add_subplot(111)
diff1 = dta.diff(11)
print(diff1.plot(ax=ax1))
# Out:
# Axes(0.125,0.125;0.775x0.775)
